# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
np.random.seed(0)

# %%
X1 = np.array([[-1,1]]) + 0.5*np.random.randn(100,2)
X2 = np.array([[1,1]]) + 0.5*np.random.randn(100,2)
X3 = np.array([[-1,-1]]) + 0.5*np.random.randn(100,2)

# %%
X = np.vstack([X1,X2,X3])
y = np.hstack([[0]*100,[1]*100,[2]*100])

# %%
X.shape,Y.shape
# Out:
# ((300, 2), (300,))

# %%
cols = ['blue', 'red', 'green']
fig, gs = plt.figure(figsize=(12,5)), gridspec.GridSpec(1, 2)

ax = []
for i in range(2):
    ax.append(fig.add_subplot(gs[i]))
    ax[i].set_xlim((-2.5, 2.5)), ax[i].set_ylim((-2.5, 2.5))

for k in np.unique(y):
    ax[0].plot(X[y==k,0], X[y==k,1], 'o', 
               label='класс {}'.format(k), color=cols[k])
    ax[1].plot(X[y==k,0], X[y==k,1], 'o', 
               label='класс {}'.format(k), color=cols[k])
