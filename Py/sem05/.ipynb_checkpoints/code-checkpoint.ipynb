# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv',float_precision='high')

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#         TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 0    3.159675e+08  00000000-0000-0000-0000-000000000000          AV
# 1    3.159675e+08  00000000-0000-0000-0000-000000012225      OTHERS
# 2    3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 3    3.159675e+08  00000000-0000-0000-0000-000000012134      OTHERS
# 4    3.159675e+08  00000000-0000-0000-0000-000000012145      OTHERS
# ..            ...                                   ...         ...
# 892  3.159675e+08  00000000-0000-0000-0000-000000012117       AGENT
# 893  3.159675e+08  00000000-0000-0000-0000-000000012432      OTHERS
# 894  3.159675e+08  00000000-0000-0000-0000-000000012345      OTHERS
# 895  3.159675e+08  00000000-0000-0000-0000-000000012426      OTHERS
# 896  3.159675e+08  00000000-0000-0000-0000-000000012378      OTHERS
#
#               X           Y CITY_NAME
# 0    595.551258  950.389251       MIA
# 1    588.260094  984.398232       MIA
# ...

# %%
data_without_av= data[(data.OBJECT_TYPE !='AV') & (data.OBJECT_TYPE !='AGENT')]

# %%
data_without_av
# Out:
#         TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 1    3.159675e+08  00000000-0000-0000-0000-000000012225      OTHERS
# 2    3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 3    3.159675e+08  00000000-0000-0000-0000-000000012134      OTHERS
# 4    3.159675e+08  00000000-0000-0000-0000-000000012145      OTHERS
# 5    3.159675e+08  00000000-0000-0000-0000-000000012243      OTHERS
# ..            ...                                   ...         ...
# 891  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 893  3.159675e+08  00000000-0000-0000-0000-000000012432      OTHERS
# 894  3.159675e+08  00000000-0000-0000-0000-000000012345      OTHERS
# 895  3.159675e+08  00000000-0000-0000-0000-000000012426      OTHERS
# 896  3.159675e+08  00000000-0000-0000-0000-000000012378      OTHERS
#
#               X           Y CITY_NAME
# 1    588.260094  984.398232       MIA
# 2    599.247935  920.100159       MIA
# ...

# %%
data_without_av = data_without_av[(data_without_av.groupby('TRACK_ID')['TRACK_ID'].transform('count')  >10)]

# %%
res
# Out:
#         TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 2    3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 23   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 42   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 77   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 96   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# ..            ...                                   ...         ...
# 862  3.159675e+08  00000000-0000-0000-0000-000000012434      OTHERS
# 883  3.159675e+08  00000000-0000-0000-0000-000000012434      OTHERS
# 853  3.159675e+08  00000000-0000-0000-0000-000000012435      OTHERS
# 873  3.159675e+08  00000000-0000-0000-0000-000000012435      OTHERS
# 888  3.159675e+08  00000000-0000-0000-0000-000000012435      OTHERS
#
#               X           Y CITY_NAME
# 2    599.247935  920.100159       MIA
# 23   599.270835  919.873232       MIA
# ...

# %%
res = data_without_av[(data_without_av.groupby('TRACK_ID')['X'].transform('max') - data_without_av.groupby('TRACK_ID')['X'].transform('min')) >1 & (data_without_av.groupby('TRACK_ID')['Y'].transform('max') - data_without_av.groupby('TRACK_ID')['Y'].transform('min') >1)]

# %%
res
# Out:
#         TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 1    3.159675e+08  00000000-0000-0000-0000-000000012225      OTHERS
# 2    3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 3    3.159675e+08  00000000-0000-0000-0000-000000012134      OTHERS
# 4    3.159675e+08  00000000-0000-0000-0000-000000012145      OTHERS
# 5    3.159675e+08  00000000-0000-0000-0000-000000012243      OTHERS
# ..            ...                                   ...         ...
# 887  3.159675e+08  00000000-0000-0000-0000-000000012225      OTHERS
# 890  3.159675e+08  00000000-0000-0000-0000-000000012377      OTHERS
# 891  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 894  3.159675e+08  00000000-0000-0000-0000-000000012345      OTHERS
# 896  3.159675e+08  00000000-0000-0000-0000-000000012378      OTHERS
#
#               X           Y CITY_NAME
# 1    588.260094  984.398232       MIA
# 2    599.247935  920.100159       MIA
# ...

# %%
res = res.sort_values(by=['TRACK_ID', 'TIMESTAMP'])

# %%
res
# Out:
#         TIMESTAMP                              TRACK_ID OBJECT_TYPE  \
# 2    3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 23   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 42   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 77   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# 96   3.159675e+08  00000000-0000-0000-0000-000000012000      OTHERS
# ..            ...                                   ...         ...
# 811  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 831  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 850  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 870  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
# 891  3.159675e+08  00000000-0000-0000-0000-000000012425      OTHERS
#
#               X           Y CITY_NAME
# 2    599.247935  920.100159       MIA
# 23   599.270835  919.873232       MIA
# ...

# %%
res.to_csv('result.csv',index=False)
